# %% [markdown]
# Exercício 4.1 — Relatório em TXT por linha de comando
#
# Objetivo: Gerar um arquivo .txt com estatísticas, com o nome definido pelo usuário via sys.argv.
#
# O que aprender: sys.argv, open(), escrita em arquivo, CLI.
#
# Tarefa: Adicione ao relatório a contagem por RA, ordenada pelo nome usando Insertion Sort.

# %%
# !python exercicio1.py saida_do_exercicio1.txt
# Out:
# /content/exercicio1.py:11: DtypeWarning: Columns (12,14) have mixed types. Specify dtype option on import or set low_memory=False.
#   moradores = pandas.read_csv("moradores.csv", sep = ";", decimal = ",", encoding = "utf-8-sig")
# Relatório salvo em: arquivo_de_saida.txt

# %% [markdown]
# Exercício 4.2 — Relatório interativo com menu
#
# Objetivo: Criar um programa com menu de opções na linha de comando.
#
# O que aprender: input(), laço while, separação em funções.
#
# Tarefa: Adicione a opção 4. Salvar relatório completo em TXT que chama as três funções e grava o resultado em relatorio_completo.txt.

# %%
# !python exercicio2.py
# Out:
# aguarde o carregamento dos dados (demora alguns segundos)
# /content/exercicio2.py:7: DtypeWarning: Columns (12,14) have mixed types. Specify dtype option on import or set low_memory=False.
#   mor = pd.read_csv("moradores.csv", sep=";", decimal=",", encoding="utf-8-sig")
# Traceback (most recent call last):
#   File "/content/exercicio2.py", line 46, in <module>
#     moradores, domicilios = carregar_dados()
#                             ^^^^^^^^^^^^^^^^
#   File "/content/exercicio2.py", line 8, in carregar_dados
#     dom = pd.read_excel("domicilios.xlsx")
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pandas/io/excel/_base.py", line 508, in read_excel
#     data = io.parse(
#            ^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pandas/io/excel/_base.py", line 1616, in parse
#     return self._reader.parse(
#            ^^^^^^^^^^^^^^^^^^^
# ...
